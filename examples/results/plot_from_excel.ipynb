# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('TAX_N400_2023-09-28_00-44-17.xlsx', index_col=0)
df
# Out:
#          e    x      s      c    l    tau      U      T     c2
# 0    1.000  0.0  0.916  0.084  1.0  0.080  0.426  1.571  0.345
# 1    1.105  0.0  0.945  0.160  1.0  0.148  0.518  1.576  0.370
# 2    1.211  0.0  1.000  0.211  1.0  0.190  0.603  1.587  0.413
# 3    1.316  0.0  1.070  0.246  1.0  0.218  0.684  1.604  0.466
# 4    1.421  0.0  1.150  0.271  1.0  0.238  0.762  1.626  0.524
# ..     ...  ...    ...    ...  ...    ...    ...    ...    ...
# 395  2.579  1.0  2.243  0.336  0.0  0.286  0.700  1.828  0.415
# 396  2.684  1.0  2.422  0.262  0.0  0.231  0.772  1.881  0.541
# 397  2.789  1.0  2.607  0.182  0.0  0.167  0.848  1.925  0.682
# 398  2.895  1.0  2.800  0.095  0.0  0.091  0.932  1.959  0.841
# 399  3.000  1.0  3.000  0.000  0.0  0.000  1.023  1.977  1.023
#
# [400 rows x 9 columns]

# %%
fig, ax = plt.subplots(figsize=(5,5)) #subplot_kw=dict(aspect='equal',)
_ = ax.set_xlabel(r'initial endowment $e$'); _ = ax.set_ylabel(r'disutility of working $x$')
# _ = ax.set_title(title)
scatter = ax.scatter(df['e'], df['x'], c=df['l'], s=10, cmap='autumn')
_ = fig.colorbar(scatter, label='labor supply $l$')
# fig.savefig('TAX_N400_labor', bbox_inches="tight", pad_inches=0.05)

# %%
fig, ax = plt.subplots(figsize=(5,5)) #subplot_kw=dict(aspect='equal',)
_ = ax.set_xlabel(r'initial endowment $e$'); _ = ax.set_ylabel(r'disutility of working $x$')
# _ = ax.set_title(title)
scatter = ax.scatter(df['e'], df['x'], c=df['tau'], s=10, cmap='winter')
_ = fig.colorbar(scatter, label='marginal tax rate $\tau$')
# fig.savefig('TAX_N400_tau', bbox_inches="tight", pad_inches=0.05)
